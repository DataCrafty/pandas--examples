# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/scientists.csv")
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
df.shape
# Out:
# (8, 5)

# %%
df.columns
# Out:
# Index(['Name', 'Died', 'Age', 'Occupation', 'born_datetime', 'age_60_diff'], dtype='object')

# %%
df[['Name','Age']]
# Out:
#                    Name  Age
# 0     Rosaline Franklin   37
# 1        William Gosset   61
# 2  Florence Nightingale   90
# 3           Marie Curie   66
# 4         Rachel Carson   56
# 5             John Snow   45
# 6           Alan Turing   41
# 7          Johann Gauss   77

# %%
df.iloc[1:5]
# Out:
#                    Name        Died  Age    Occupation born_datetime  \
# 1        William Gosset  1937-10-16   61  Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90         Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66       Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56     Biologist    1907-05-27
#
#    age_60_diff
# 1            1
# 2           30
# 3            6
# 4           -4

# %%
df.loc[1:2]
# Out:
#                    Name        Died  Age    Occupation born_datetime  \
# 1        William Gosset  1937-10-16   61  Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90         Nurse    1820-05-12
#
#    age_60_diff
# 1            1
# 2           30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes

# %%
type(df['Born'])
# Out:
# pandas.core.series.Series

# %%
df['Died'].dtype
# Out:
# dtype('O')

# %%
df['born_datetime'] = pd.to_datetime(df['Born'], format = "%Y-%m-%d")

# %%
df.dtypes
# Out:
# Name                     object
# Born                     object
# Died                     object
# Age                       int64
# Occupation               object
# born_datetime    datetime64[ns]
# dtype: object

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#   born_datetime
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           8 non-null      object
#  1   Born           8 non-null      object
#  2   Died           8 non-null      object
#  3   Age            8 non-null      int64
#  4   Occupation     8 non-null      object
#  5   born_datetime  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 512.0+ bytes

# %%
df.shape
# Out:
# (8, 6)

# %%
df.drop(['Born'], axis = 1, inplace = True)

# %%
df
# Out:
#                    Name        Died  Age          Occupation born_datetime
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30

# %%
df["age_60_diff"] = df['Age'] - 60
df
# Out:
#                    Name        Died  Age          Occupation born_datetime  \
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
#
#    age_60_diff
# 0          -23
# 1            1
# 2           30
# 3            6
# 4           -4
# 5          -15
# 6          -19
# 7           17

# %%
df.to_csv("New_Scientist_info.csv", index = False)

# %%
df
# Out:
#                    Name        Died  Age          Occupation born_datetime  \
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
#
#    age_60_diff
# 0          -23
# 1            1
# 2           30
# 3            6
# 4           -4
# 5          -15
# 6          -19
# 7           17

# %%
pd.read_csv("New_Scientist_info.csv")
# Out:
#                    Name        Died  Age          Occupation born_datetime  \
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
#
#    age_60_diff
# 0          -23
# 1            1
# 2           30
# 3            6
# 4           -4
# 5          -15
# 6          -19
# 7           17

# %%
df
# Out:
#                    Name        Died  Age          Occupation born_datetime  \
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
#
#    age_60_diff
# 0          -23
# 1            1
# 2           30
# 3            6
# 4           -4
# 5          -15
# 6          -19
# 7           17

# %%
df.loc[df['Name']=='Rachel Carson']
# Out:
#             Name        Died  Age Occupation born_datetime  age_60_diff
# 4  Rachel Carson  1964-04-14   56  Biologist    1907-05-27           -4

# %%
df.loc[df['Occupation']=='Chemist']
# Out:
#                 Name        Died  Age Occupation born_datetime  age_60_diff
# 0  Rosaline Franklin  1958-04-16   37    Chemist    1920-07-25          -23
# 3        Marie Curie  1934-07-04   66    Chemist    1867-11-07            6

# %%
df.describe()  # to find high level like mean,median,standard deviation
# Out:
#              Age  age_60_diff
# count   8.000000     8.000000
# mean   59.125000    -0.875000
# std    18.325918    18.325918
# min    37.000000   -23.000000
# 25%    44.000000   -16.000000
# 50%    58.500000    -1.500000
# 75%    68.750000     8.750000
# max    90.000000    30.000000

# %%
df.sort_values('Name',ascending = False)
# Out:
#                    Name        Died  Age          Occupation born_datetime  \
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
#
#    age_60_diff
# 1            1
# 0          -23
# 4           -4
# 3            6
# 5          -15
# 7           17
# 2           30
# 6          -19

# %%
df = df.drop(columns=['age_60_diff'])

# %%
df
# Out:
#                    Name        Died  Age          Occupation born_datetime
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30

# %%
cols = list(df.columns.values)

# %%
cols
# Out:
# ['Name', 'Died', 'Age', 'Occupation', 'born_datetime']

# %%
df.loc[df['Occupation']=='Chemist'].value_counts()
# Out:
# Name               Died        Age  Occupation  born_datetime
# Marie Curie        1934-07-04  66   Chemist     1867-11-07       1
# Rosaline Franklin  1958-04-16  37   Chemist     1920-07-25       1
# dtype: int64

# %%
df['Age']>41
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
df.loc[~df["Name"].str.contains('Marie Curie ')]
# Out:
#                    Name        Died  Age          Occupation born_datetime
# 0     Rosaline Franklin  1958-04-16   37             Chemist    1920-07-25
# 1        William Gosset  1937-10-16   61        Statistician    1876-06-13
# 2  Florence Nightingale  1910-08-13   90               Nurse    1820-05-12
# 3           Marie Curie  1934-07-04   66             Chemist    1867-11-07
# 4         Rachel Carson  1964-04-14   56           Biologist    1907-05-27
# 5             John Snow  1858-06-16   45           Physician    1813-03-15
# 6           Alan Turing  1954-06-07   41  Computer Scientist    1912-06-23
# 7          Johann Gauss  1855-02-23   77       Mathematician    1777-04-30
